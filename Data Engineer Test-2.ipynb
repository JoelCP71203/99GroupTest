# %%
import pandas as pd

csv_file_path = './data/listings.csv'

listings_df = pd.read_csv(csv_file_path)

numerical_description = listings_df.describe()

mode_ptype = listings_df['_ptype'].mode()[0]
mode_ltype = listings_df['_ltype'].mode()[0]
mode_sold = listings_df['sold'].mode()[0]

missing_values = listings_df.isnull().sum()
duplicates = listings_df.duplicated().sum()

cleaned_listings_df = listings_df.dropna(subset=['price', 'sold'])

cleaned_listings_df['bedRooms'].fillna(cleaned_listings_df['bedRooms'].median(), inplace=True)
cleaned_listings_df['bathRooms'].fillna(cleaned_listings_df['bathRooms'].median(), inplace=True)
cleaned_listings_df['landSize'].fillna(cleaned_listings_df['landSize'].median(), inplace=True)
cleaned_listings_df['buildingSize'].fillna(cleaned_listings_df['buildingSize'].median(), inplace=True)
cleaned_listings_df['garages'].fillna(cleaned_listings_df['garages'].median(), inplace=True)

cleaned_listings_df['_ptype'].fillna(mode_ptype, inplace=True)
cleaned_listings_df['_ltype'].fillna(mode_ltype, inplace=True)

cleaned_missing_values = cleaned_listings_df.isnull().sum()
cleaned_missing_values
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_listings_df['bedRooms'].fillna(cleaned_listings_df['bedRooms'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_listings_df['bedRooms'].fillna(cleaned_listings_df['bedRooms'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_listings_df['bathRooms'].fillna(cleaned_listings_df['bathRooms'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_listings_df['bathRooms'].fillna(cleaned_listings_df['bathRooms'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_listings_df['landSize'].fillna(cleaned_listings_df['landSize'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_listings_df['landSize'].fillna(cleaned_listings_df['landSize'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_listings_df['buildingSize'].fillna(cleaned_listings_df['buildingSize'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_listings_df['buildingSize'].fillna(cleaned_listings_df['buildingSize'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_listings_df['garages'].fillna(cleaned_listings_df['garages'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_listings_df['garages'].fillna(cleaned_listings_df['garages'].median(), inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_listings_df['_ptype'].fillna(mode_ptype, inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_listings_df['_ptype'].fillna(mode_ptype, inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_listings_df['_ltype'].fillna(mode_ltype, inplace=True)
# C:\Users\ACER\AppData\Local\Temp\ipykernel_35272\1134469913.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_listings_df['_ltype'].fillna(mode_ltype, inplace=True)
# id              32
# _ptype           0
# _ltype           0
# price            0
# kabkoId         40
# bedRooms         0
# bathRooms        0
# landSize         0
# buildingSize     0
# garages          0
# sold             0
# dtype: int64
